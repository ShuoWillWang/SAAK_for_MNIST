# %%
import torch.nn as nn
import torch.nn.init as init
import torch
from math import sqrt
import numpy as np
import torch.nn.functional as F
from torch.autograd import Variable
import gzip
import cPickle
from sklearn.decomposition import PCA
import random
from sklearn import preprocessing
from torchvision import datasets, transforms
import torch.optim as optim

# %%
class SaakNet(nn.Module):
    def __init__(self):
        super(SaakNet, self).__init__()
        # 1 input image channel, 6 output channels, 5x5 square convolution
        # kernel
        self.kernel_size = 2
        
        # conv1
        curL_in = 1; curL_out = 3
        self.conv1 = nn.Conv2d(curL_in, curL_out, self.kernel_size, stride=self.kernel_size, bias = False, padding = 2) 
        init.xavier_uniform(self.conv1.weight, init.calculate_gain('relu'))
        self.conv1_b = nn.Conv2d(curL_in, 1, self.kernel_size, stride=self.kernel_size, bias = False, padding = 2)
        f1 = np.ones([1,curL_in,self.kernel_size,self.kernel_size])
        self.f1 = torch.from_numpy(f1/np.linalg.norm(f1))
        self.conv1_b.weight = torch.nn.Parameter(self.f1.float())
        
        # conv2
        curL_in = curL_out * 2 + 1; curL_out = 27
        self.conv2 = nn.Conv2d(curL_in, curL_out, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0) 
        init.xavier_uniform(self.conv2.weight, init.calculate_gain('relu'))
        self.conv2_b = nn.Conv2d(curL_in, 1, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0)
        f2 = np.ones([1,curL_in,self.kernel_size,self.kernel_size])
        self.f2 = torch.from_numpy(f2/np.linalg.norm(f2))
        self.conv2_b.weight = torch.nn.Parameter(self.f2.float())
        
        # conv3
        curL_in = curL_out * 2 + 1; curL_out = 220
        self.conv3 = nn.Conv2d(curL_in, curL_out, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0)
        init.xavier_uniform(self.conv3.weight, init.calculate_gain('relu'))
        self.conv3_b = nn.Conv2d(curL_in, 1, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0)
        f3 = np.ones([1,curL_in,self.kernel_size,self.kernel_size])
        self.f3 = torch.from_numpy(f3/np.linalg.norm(f3))
        self.conv3_b.weight = torch.nn.Parameter(self.f3.float())
        
        # conv4
        curL_in = curL_out * 2 + 1; curL_out = 1800
        self.conv4 = nn.Conv2d(curL_in, curL_out, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0)
        init.xavier_uniform(self.conv4.weight, init.calculate_gain('relu'))
        self.conv4_b = nn.Conv2d(curL_in, 1, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0)
        f4 = np.ones([1,curL_in,self.kernel_size,self.kernel_size])
        self.f4 = torch.from_numpy(f4/np.linalg.norm(f4))
        self.conv4_b.weight = torch.nn.Parameter(self.f4.float())
        
        # conv5
        curL_in = curL_out * 2 + 1; curL_out = 2000
        self.conv5 = nn.Conv2d(curL_in, curL_out, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0)
        init.xavier_uniform(self.conv5.weight, init.calculate_gain('relu'))
        self.conv5_b = nn.Conv2d(curL_in, 1, self.kernel_size, stride=self.kernel_size, bias = False, padding = 0)
        f5 = np.ones([1,curL_in,self.kernel_size,self.kernel_size])
        self.f5 = torch.from_numpy(f5/np.linalg.norm(f5))
        self.conv5_b.weight = torch.nn.Parameter(self.f5.float())
        
        # fc6
        self.fc6 = nn.Linear(4001 * 1 * 1, 333)
        init.xavier_uniform(self.fc6.weight)
        
        # fc7
        self.fc7 = nn.Linear(667, 55)
        init.xavier_uniform(self.fc7.weight)
        
        # fc8
        self.fc8 = nn.Linear(111, 10)
        init.xavier_uniform(self.fc8.weight)
        
    def In_DC(self, ac):
        temp = ac.view(ac.size(0), ac.size(1), -1)
        temp = temp.view(temp.size(0), temp.size(1) * 4, -1)
        temp = temp.view(ac.size(0), temp.size(1), ac.size(2) / 2, ac.size(3) / 2)
        temp = torch.sum(temp, 1)
        return temp
        
    def Augment(self, ac, dc):
        return F.relu(torch.cat((ac,-ac, dc),1))
    
    def Augment_fc(self, ac):
        dc = torch.sum(ac, 1,  keepdim=True)
        return F.relu(torch.cat((ac,-ac, dc),1))
    
    def forward(self, input):
        f2 = self.Augment(self.conv1(input),self.conv1_b(input))
        f3 = self.Augment(self.conv2(f2),self.conv2_b(f2))
        f4 = self.Augment(self.conv3(f3),self.conv3_b(f3))
        f5 = self.Augment(self.conv4(f4),self.conv4_b(f4))
        output = self.Augment(self.conv5(f5),self.conv5_b(f5))
#         print output.size()
        output = output.view(-1, 4001)
#         print output.size()
        fc6 = self.Augment_fc(self.fc6(output))
#         print fc6.size()
        fc7 = self.Augment_fc(self.fc7(fc6))
#         print fc7.size()
        fc8 = self.fc8(fc7)
#         print fc8.size()
        return fc8

# %%
f = gzip.open('mnist.pkl.gz', 'rb')
train_set, valid_set, test_set = cPickle.load(f)
f.close()
train_data = train_set[0].reshape(-1,1,28,28)
valid_data = valid_set[0].reshape(-1,1,28,28)
test_data = test_set[0].reshape(-1,1,28,28)
train_label = train_set[1]
valid_label = valid_set[1]
test_label = test_set[1]

# %%
def accuracy(output, label):
    max_lab = torch.max(output, 1)[1]
    acc = (max_lab == label).float().sum() / float(label.size(0))
    return acc.data[0]

# %%
def acc_batch(net, data, label, batch_size):
    avg = 0
    for j in range(data.shape[0] // batch_size):
        X = data[j * batch_size: (j + 1) * batch_size,:]
        Y = label[j * batch_size: (j + 1) * batch_size]
        ind = np.random.permutation(X.shape[0])
        X = X[ind,:]
        Y = Y[ind]
        X_ = Variable(torch.from_numpy(X)).cuda()
        Y_ = Variable(torch.from_numpy(Y.astype(int))).cuda()
        Y_O = net(X_)
        acc = accuracy(Y_O, Y_)
        avg = avg + acc / (num_testing // batch_size)
    return avg

# %%
net = SaakNet()
net = net.cuda()
optimizer = optim.Adam(net.parameters(), lr=1e-4, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)
criterion = nn.CrossEntropyLoss()

batch_size = 100
num_epoch = 100
num_training = train_data.shape[0]
num_testing = test_data.shape[0]
log_step = 100;
step = 0

# val_data = Variable(torch.DoubleTensor(valid_data)).cuda()
# val_label = Variable(torch.LongTensor(valid_label.astype(int))).cuda()

for i in range(num_epoch):
    print("Train for epoch %d" % i)
    inda = np.random.permutation(num_training // batch_size)
    for j in range(num_training // batch_size):
        X = train_data[inda[j] * batch_size: (inda[j] + 1) * batch_size,:]
        Y = train_label[inda[j] * batch_size: (inda[j] + 1) * batch_size]
        ind = np.random.permutation(X.shape[0])
        X = X[ind,:]
        Y = Y[ind]
        X_ = Variable(torch.from_numpy(X)).cuda()
        Y_ = Variable(torch.from_numpy(Y.astype(int))).cuda()
        Y_O = net(X_)
        loss = criterion(Y_O, Y_)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        acc = accuracy(Y_O, Y_)
        if(step % log_step == 0):
            print('iteration (%d): loss = %.3f, accuracy = %.3f' % (step, loss.data[0], acc))
        step += 1
        
    print("validation for epoch %d" % i)
    val_accuracy = acc_batch(net, valid_data, valid_label, batch_size)
#     val_lab = net(val_data)
#     val_accuracy = accuracy(val_lab, val_label)
    print("validation result is %.5f" % val_accuracy)
    test_accuracy = acc_batch(net, test_data, test_label, batch_size)
    print("test result is %.5f" % test_accuracy)

# avg = 0
# for j in range(num_testing // batch_size):
#     X = test_data[j * batch_size: (j + 1) * batch_size,:]
#     Y = test_label[j * batch_size: (j + 1) * batch_size]
#     ind = np.random.permutation(X.shape[0])
#     X = X[ind,:]
#     Y = Y[ind]
#     X_ = Variable(torch.DoubleTensor(X)).cuda()
#     Y_ = Variable(torch.LongTensor(Y.astype(int))).cuda()
#     Y_O = net(X_)
#     acc = accuracy(Y_O, Y_)
#     avg = avg + acc / (num_testing // batch_size)
    
# print("test result is %.5f" % avg)
# Out:
# Train for epoch 0
# iteration (0): loss = 2.357, accuracy = 0.100
# iteration (100): loss = 0.152, accuracy = 0.950
# iteration (200): loss = 0.483, accuracy = 0.850
# iteration (300): loss = 0.121, accuracy = 0.960
# iteration (400): loss = 0.181, accuracy = 0.940
# validation for epoch 0
# validation result is 0.96930
# test result is 0.96900
# Train for epoch 1
# iteration (500): loss = 0.082, accuracy = 0.960
# iteration (600): loss = 0.187, accuracy = 0.950
# iteration (700): loss = 0.028, accuracy = 1.000
# iteration (800): loss = 0.104, accuracy = 0.970
# iteration (900): loss = 0.049, accuracy = 0.980
# validation for epoch 1
# validation result is 0.97800
# test result is 0.97470
# Train for epoch 2
# iteration (1000): loss = 0.129, accuracy = 0.980
# iteration (1100): loss = 0.023, accuracy = 1.000
# iteration (1200): loss = 0.062, accuracy = 0.980
# iteration (1300): loss = 0.003, accuracy = 1.000
# iteration (1400): loss = 0.016, accuracy = 0.990
# validation for epoch 2
# validation result is 0.98050
# test result is 0.97970
# Train for epoch 3
# iteration (1500): loss = 0.019, accuracy = 0.990
# iteration (1600): loss = 0.014, accuracy = 1.000
# iteration (1700): loss = 0.090, accuracy = 0.970
# iteration (1800): loss = 0.028, accuracy = 0.990
# iteration (1900): loss = 0.060, accuracy = 0.970
# validation for epoch 3
# validation result is 0.98020
# test result is 0.98040
# Train for epoch 4
# iteration (2000): loss = 0.018, accuracy = 1.000
# iteration (2100): loss = 0.038, accuracy = 0.990
# iteration (2200): loss = 0.008, accuracy = 1.000
# iteration (2300): loss = 0.007, accuracy = 1.000
# iteration (2400): loss = 0.005, accuracy = 1.000
# validation for epoch 4
# validation result is 0.98040
# test result is 0.98100
# Train for epoch 5
# iteration (2500): loss = 0.011, accuracy = 1.000
# iteration (2600): loss = 0.067, accuracy = 0.990
# iteration (2700): loss = 0.051, accuracy = 0.970
# iteration (2800): loss = 0.012, accuracy = 0.990
# iteration (2900): loss = 0.033, accuracy = 0.970
# validation for epoch 5
# validation result is 0.97800
# test result is 0.97790
# Train for epoch 6
# iteration (3000): loss = 0.007, accuracy = 1.000
# iteration (3100): loss = 0.003, accuracy = 1.000
# iteration (3200): loss = 0.006, accuracy = 1.000
# iteration (3300): loss = 0.005, accuracy = 1.000
# iteration (3400): loss = 0.012, accuracy = 1.000
# validation for epoch 6
# validation result is 0.98220
# test result is 0.98090
# Train for epoch 7
# iteration (3500): loss = 0.039, accuracy = 0.990
# iteration (3600): loss = 0.006, accuracy = 1.000
# iteration (3700): loss = 0.008, accuracy = 1.000
# iteration (3800): loss = 0.008, accuracy = 1.000
# iteration (3900): loss = 0.012, accuracy = 1.000
# validation for epoch 7
# validation result is 0.98200
# test result is 0.98100
# Train for epoch 8
# iteration (4000): loss = 0.110, accuracy = 0.970
# iteration (4100): loss = 0.002, accuracy = 1.000
# iteration (4200): loss = 0.015, accuracy = 0.990
# iteration (4300): loss = 0.006, accuracy = 1.000
# iteration (4400): loss = 0.016, accuracy = 0.990
# validation for epoch 8
# validation result is 0.98200
# test result is 0.98070
# Train for epoch 9
# iteration (4500): loss = 0.006, accuracy = 1.000
# iteration (4600): loss = 0.006, accuracy = 1.000
# iteration (4700): loss = 0.001, accuracy = 1.000
# iteration (4800): loss = 0.002, accuracy = 1.000
# iteration (4900): loss = 0.005, accuracy = 1.000
# validation for epoch 9
# validation result is 0.97960
# test result is 0.97650
# Train for epoch 10
# iteration (5000): loss = 0.007, accuracy = 1.000
# iteration (5100): loss = 0.008, accuracy = 0.990
# iteration (5200): loss = 0.001, accuracy = 1.000
# iteration (5300): loss = 0.001, accuracy = 1.000
# iteration (5400): loss = 0.001, accuracy = 1.000
# validation for epoch 10
# validation result is 0.98580
# test result is 0.98410
# Train for epoch 11
# iteration (5500): loss = 0.001, accuracy = 1.000
# iteration (5600): loss = 0.011, accuracy = 1.000
# iteration (5700): loss = 0.001, accuracy = 1.000
# iteration (5800): loss = 0.023, accuracy = 0.980
# iteration (5900): loss = 0.004, accuracy = 1.000
# validation for epoch 11
# validation result is 0.98100
# test result is 0.98140
# Train for epoch 12
# iteration (6000): loss = 0.014, accuracy = 0.990
# iteration (6100): loss = 0.067, accuracy = 0.990
# iteration (6200): loss = 0.003, accuracy = 1.000
# iteration (6300): loss = 0.009, accuracy = 0.990
# iteration (6400): loss = 0.000, accuracy = 1.000
# validation for epoch 12
# validation result is 0.98100
# test result is 0.98040
# Train for epoch 13
# iteration (6500): loss = 0.007, accuracy = 1.000
# iteration (6600): loss = 0.002, accuracy = 1.000
# iteration (6700): loss = 0.007, accuracy = 1.000
# iteration (6800): loss = 0.003, accuracy = 1.000
# iteration (6900): loss = 0.019, accuracy = 0.980
# validation for epoch 13
# validation result is 0.98700
# test result is 0.98670
# Train for epoch 14
# iteration (7000): loss = 0.000, accuracy = 1.000
# iteration (7100): loss = 0.057, accuracy = 0.980
# iteration (7200): loss = 0.011, accuracy = 0.990
# iteration (7300): loss = 0.000, accuracy = 1.000
# iteration (7400): loss = 0.116, accuracy = 0.980
# validation for epoch 14
# validation result is 0.98470
# test result is 0.98290
# Train for epoch 15
# iteration (7500): loss = 0.003, accuracy = 1.000
# iteration (7600): loss = 0.004, accuracy = 1.000
# iteration (7700): loss = 0.149, accuracy = 0.970
# iteration (7800): loss = 0.001, accuracy = 1.000
# iteration (7900): loss = 0.001, accuracy = 1.000
# validation for epoch 15
# validation result is 0.98510
# test result is 0.98430
# Train for epoch 16
# iteration (8000): loss = 0.001, accuracy = 1.000
# iteration (8100): loss = 0.002, accuracy = 1.000
# iteration (8200): loss = 0.000, accuracy = 1.000
# iteration (8300): loss = 0.000, accuracy = 1.000
# iteration (8400): loss = 0.001, accuracy = 1.000
# validation for epoch 16
# validation result is 0.98700
# test result is 0.98630
# Train for epoch 17
# iteration (8500): loss = 0.001, accuracy = 1.000
# iteration (8600): loss = 0.001, accuracy = 1.000
# iteration (8700): loss = 0.000, accuracy = 1.000
# iteration (8800): loss = 0.004, accuracy = 1.000
# iteration (8900): loss = 0.020, accuracy = 0.990
# validation for epoch 17
# validation result is 0.97870
# test result is 0.97930
# Train for epoch 18
# iteration (9000): loss = 0.006, accuracy = 1.000
# iteration (9100): loss = 0.012, accuracy = 0.990
# iteration (9200): loss = 0.011, accuracy = 0.990
# iteration (9300): loss = 0.012, accuracy = 0.990
# iteration (9400): loss = 0.105, accuracy = 0.990
# validation for epoch 18
# validation result is 0.98380
# test result is 0.98340
# Train for epoch 19
# iteration (9500): loss = 0.000, accuracy = 1.000
# iteration (9600): loss = 0.002, accuracy = 1.000
# iteration (9700): loss = 0.000, accuracy = 1.000
# iteration (9800): loss = 0.013, accuracy = 0.990
# iteration (9900): loss = 0.006, accuracy = 1.000
# validation for epoch 19
# validation result is 0.98540
# test result is 0.98640
# Train for epoch 20
# iteration (10000): loss = 0.000, accuracy = 1.000
# iteration (10100): loss = 0.003, accuracy = 1.000
# iteration (10200): loss = 0.001, accuracy = 1.000
# iteration (10300): loss = 0.000, accuracy = 1.000
# iteration (10400): loss = 0.001, accuracy = 1.000
# validation for epoch 20
# validation result is 0.98530
# test result is 0.98510
# Train for epoch 21
# iteration (10500): loss = 0.000, accuracy = 1.000
# iteration (10600): loss = 0.000, accuracy = 1.000
# iteration (10700): loss = 0.001, accuracy = 1.000
# iteration (10800): loss = 0.001, accuracy = 1.000
# iteration (10900): loss = 0.000, accuracy = 1.000
# validation for epoch 21
# validation result is 0.98580
# test result is 0.98580
# Train for epoch 22
# iteration (11000): loss = 0.028, accuracy = 0.990
# iteration (11100): loss = 0.001, accuracy = 1.000
# iteration (11200): loss = 0.000, accuracy = 1.000
# iteration (11300): loss = 0.013, accuracy = 0.990
# iteration (11400): loss = 0.000, accuracy = 1.000
# validation for epoch 22
# validation result is 0.98230
# test result is 0.98060
# Train for epoch 23
# iteration (11500): loss = 0.002, accuracy = 1.000
# iteration (11600): loss = 0.045, accuracy = 0.990
# iteration (11700): loss = 0.000, accuracy = 1.000
# iteration (11800): loss = 0.121, accuracy = 0.970
# iteration (11900): loss = 0.020, accuracy = 0.990
# validation for epoch 23
# validation result is 0.98480
# test result is 0.98440
# Train for epoch 24
# iteration (12000): loss = 0.003, accuracy = 1.000
# iteration (12100): loss = 0.022, accuracy = 0.980
# iteration (12200): loss = 0.000, accuracy = 1.000
# iteration (12300): loss = 0.000, accuracy = 1.000
# iteration (12400): loss = 0.000, accuracy = 1.000
# validation for epoch 24
# validation result is 0.98730
# test result is 0.98710
# Train for epoch 25
# iteration (12500): loss = 0.000, accuracy = 1.000
# iteration (12600): loss = 0.002, accuracy = 1.000
# iteration (12700): loss = 0.002, accuracy = 1.000
# iteration (12800): loss = 0.000, accuracy = 1.000
# iteration (12900): loss = 0.000, accuracy = 1.000
# validation for epoch 25
# validation result is 0.98360
# test result is 0.98400
# Train for epoch 26
# iteration (13000): loss = 0.001, accuracy = 1.000
# iteration (13100): loss = 0.016, accuracy = 0.990
# iteration (13200): loss = 0.001, accuracy = 1.000
# iteration (13300): loss = 0.000, accuracy = 1.000
# iteration (13400): loss = 0.003, accuracy = 1.000
# validation for epoch 26
# validation result is 0.98710
# test result is 0.98790
# Train for epoch 27
# iteration (13500): loss = 0.000, accuracy = 1.000
# iteration (13600): loss = 0.020, accuracy = 0.990
# iteration (13700): loss = 0.000, accuracy = 1.000
# iteration (13800): loss = 0.001, accuracy = 1.000
# iteration (13900): loss = 0.001, accuracy = 1.000
# validation for epoch 27
# validation result is 0.98360
# test result is 0.98480
# Train for epoch 28
# iteration (14000): loss = 0.000, accuracy = 1.000
# iteration (14100): loss = 0.001, accuracy = 1.000
# iteration (14200): loss = 0.016, accuracy = 0.990
# iteration (14300): loss = 0.001, accuracy = 1.000
# iteration (14400): loss = 0.001, accuracy = 1.000
# validation for epoch 28
# validation result is 0.98590
# test result is 0.98340
# Train for epoch 29
# iteration (14500): loss = 0.000, accuracy = 1.000
# iteration (14600): loss = 0.005, accuracy = 1.000
# iteration (14700): loss = 0.000, accuracy = 1.000
# iteration (14800): loss = 0.000, accuracy = 1.000
# iteration (14900): loss = 0.000, accuracy = 1.000
# validation for epoch 29
# validation result is 0.98490
# test result is 0.98620
# Train for epoch 30
# iteration (15000): loss = 0.001, accuracy = 1.000
# iteration (15100): loss = 0.031, accuracy = 0.990
# iteration (15200): loss = 0.006, accuracy = 1.000
# iteration (15300): loss = 0.021, accuracy = 0.990
# iteration (15400): loss = 0.025, accuracy = 0.990
# validation for epoch 30
# validation result is 0.98020
# test result is 0.98130
# Train for epoch 31
# iteration (15500): loss = 0.000, accuracy = 1.000
# iteration (15600): loss = 0.000, accuracy = 1.000
# iteration (15700): loss = 0.000, accuracy = 1.000
# iteration (15800): loss = 0.014, accuracy = 0.990
# iteration (15900): loss = 0.019, accuracy = 0.990
# validation for epoch 31
# validation result is 0.98770
# test result is 0.98550
# Train for epoch 32
# iteration (16000): loss = 0.000, accuracy = 1.000
# iteration (16100): loss = 0.000, accuracy = 1.000
# iteration (16200): loss = 0.000, accuracy = 1.000
# iteration (16300): loss = 0.025, accuracy = 0.990
# iteration (16400): loss = 0.001, accuracy = 1.000
# validation for epoch 32
# validation result is 0.98660
# test result is 0.98710
# Train for epoch 33
# iteration (16500): loss = 0.000, accuracy = 1.000
# iteration (16600): loss = 0.000, accuracy = 1.000
# iteration (16700): loss = 0.000, accuracy = 1.000
# iteration (16800): loss = 0.000, accuracy = 1.000
# iteration (16900): loss = 0.026, accuracy = 0.990
# validation for epoch 33
# validation result is 0.98090
# test result is 0.97730
# Train for epoch 34
# iteration (17000): loss = 0.007, accuracy = 1.000
# iteration (17100): loss = 0.045, accuracy = 0.980
# iteration (17200): loss = 0.000, accuracy = 1.000
# iteration (17300): loss = 0.001, accuracy = 1.000
# iteration (17400): loss = 0.001, accuracy = 1.000
# validation for epoch 34
# validation result is 0.98580
# test result is 0.98550
# Train for epoch 35
# iteration (17500): loss = 0.000, accuracy = 1.000
# iteration (17600): loss = 0.001, accuracy = 1.000
# iteration (17700): loss = 0.001, accuracy = 1.000
# iteration (17800): loss = 0.001, accuracy = 1.000
# iteration (17900): loss = 0.009, accuracy = 1.000
# validation for epoch 35
# validation result is 0.98690
# test result is 0.98670
# Train for epoch 36
# iteration (18000): loss = 0.000, accuracy = 1.000
# iteration (18100): loss = 0.000, accuracy = 1.000
# iteration (18200): loss = 0.000, accuracy = 1.000
# iteration (18300): loss = 0.000, accuracy = 1.000
# iteration (18400): loss = 0.000, accuracy = 1.000
# validation for epoch 36
# validation result is 0.98540
# test result is 0.98500
# Train for epoch 37
# iteration (18500): loss = 0.019, accuracy = 0.990
# iteration (18600): loss = 0.003, accuracy = 1.000
# iteration (18700): loss = 0.000, accuracy = 1.000
# iteration (18800): loss = 0.015, accuracy = 0.990
# iteration (18900): loss = 0.002, accuracy = 1.000
# validation for epoch 37
# validation result is 0.98650
# test result is 0.98630
# Train for epoch 38
# iteration (19000): loss = 0.002, accuracy = 1.000
# iteration (19100): loss = 0.000, accuracy = 1.000
# iteration (19200): loss = 0.004, accuracy = 1.000
# iteration (19300): loss = 0.000, accuracy = 1.000
# iteration (19400): loss = 0.001, accuracy = 1.000
# validation for epoch 38
# validation result is 0.98720
# test result is 0.98640
# Train for epoch 39
# iteration (19500): loss = 0.001, accuracy = 1.000
# iteration (19600): loss = 0.007, accuracy = 1.000
# iteration (19700): loss = 0.000, accuracy = 1.000
# iteration (19800): loss = 0.001, accuracy = 1.000
# iteration (19900): loss = 0.000, accuracy = 1.000
# validation for epoch 39
# validation result is 0.98660
# test result is 0.98670
# Train for epoch 40
# iteration (20000): loss = 0.001, accuracy = 1.000
# iteration (20100): loss = 0.000, accuracy = 1.000
# iteration (20200): loss = 0.000, accuracy = 1.000
# iteration (20300): loss = 0.000, accuracy = 1.000
# iteration (20400): loss = 0.008, accuracy = 1.000
# validation for epoch 40
# validation result is 0.98770
# test result is 0.98590
# Train for epoch 41
# iteration (20500): loss = 0.000, accuracy = 1.000
# iteration (20600): loss = 0.000, accuracy = 1.000
# iteration (20700): loss = 0.023, accuracy = 0.990
# iteration (20800): loss = 0.000, accuracy = 1.000
# iteration (20900): loss = 0.000, accuracy = 1.000
# validation for epoch 41
# validation result is 0.98590
# test result is 0.98720
# Train for epoch 42
# iteration (21000): loss = 0.000, accuracy = 1.000
# iteration (21100): loss = 0.000, accuracy = 1.000
# iteration (21200): loss = 0.000, accuracy = 1.000
# iteration (21300): loss = 0.074, accuracy = 0.990
# iteration (21400): loss = 0.035, accuracy = 0.980
# validation for epoch 42
# validation result is 0.98360
# test result is 0.98520
# Train for epoch 43
# iteration (21500): loss = 0.004, accuracy = 1.000
# iteration (21600): loss = 0.000, accuracy = 1.000
# iteration (21700): loss = 0.000, accuracy = 1.000
# iteration (21800): loss = 0.000, accuracy = 1.000
# iteration (21900): loss = 0.002, accuracy = 1.000
# validation for epoch 43
# validation result is 0.98870
# test result is 0.98900
# Train for epoch 44
# iteration (22000): loss = 0.000, accuracy = 1.000
# iteration (22100): loss = 0.000, accuracy = 1.000
# iteration (22200): loss = 0.012, accuracy = 0.990
# iteration (22300): loss = 0.000, accuracy = 1.000
# iteration (22400): loss = 0.000, accuracy = 1.000
# validation for epoch 44
# validation result is 0.98590
# test result is 0.98420
# Train for epoch 45
# iteration (22500): loss = 0.000, accuracy = 1.000
# iteration (22600): loss = 0.000, accuracy = 1.000
# iteration (22700): loss = 0.001, accuracy = 1.000
# iteration (22800): loss = 0.000, accuracy = 1.000
# iteration (22900): loss = 0.000, accuracy = 1.000
# validation for epoch 45
# validation result is 0.98530
# test result is 0.98410
# Train for epoch 46
# iteration (23000): loss = 0.012, accuracy = 0.990
# iteration (23100): loss = 0.000, accuracy = 1.000
# iteration (23200): loss = 0.031, accuracy = 0.990
# iteration (23300): loss = 0.000, accuracy = 1.000
# iteration (23400): loss = 0.084, accuracy = 0.990
# validation for epoch 46
# validation result is 0.98800
# test result is 0.98680
# Train for epoch 47
# iteration (23500): loss = 0.000, accuracy = 1.000
# iteration (23600): loss = 0.000, accuracy = 1.000
# iteration (23700): loss = 0.000, accuracy = 1.000
# iteration (23800): loss = 0.000, accuracy = 1.000
# iteration (23900): loss = 0.000, accuracy = 1.000
# validation for epoch 47
# validation result is 0.98890
# test result is 0.98730
# Train for epoch 48
# iteration (24000): loss = 0.000, accuracy = 1.000
# iteration (24100): loss = 0.000, accuracy = 1.000
# iteration (24200): loss = 0.006, accuracy = 1.000
# iteration (24300): loss = 0.007, accuracy = 1.000
# iteration (24400): loss = 0.024, accuracy = 0.990
# validation for epoch 48
# validation result is 0.98580
# test result is 0.98760
# Train for epoch 49
# iteration (24500): loss = 0.000, accuracy = 1.000
# iteration (24600): loss = 0.001, accuracy = 1.000
# iteration (24700): loss = 0.000, accuracy = 1.000
# iteration (24800): loss = 0.000, accuracy = 1.000
# iteration (24900): loss = 0.010, accuracy = 0.990
# validation for epoch 49
# validation result is 0.98460
# test result is 0.98520
# Train for epoch 50
# iteration (25000): loss = 0.000, accuracy = 1.000
# iteration (25100): loss = 0.000, accuracy = 1.000
# iteration (25200): loss = 0.001, accuracy = 1.000
# iteration (25300): loss = 0.000, accuracy = 1.000
# iteration (25400): loss = 0.000, accuracy = 1.000
# validation for epoch 50
# validation result is 0.98810
# test result is 0.98770
# Train for epoch 51
# iteration (25500): loss = 0.004, accuracy = 1.000
# iteration (25600): loss = 0.000, accuracy = 1.000
# iteration (25700): loss = 0.000, accuracy = 1.000
# iteration (25800): loss = 0.000, accuracy = 1.000
# iteration (25900): loss = 0.000, accuracy = 1.000
# validation for epoch 51
# validation result is 0.98650
# test result is 0.98500
# Train for epoch 52
# iteration (26000): loss = 0.003, accuracy = 1.000
# iteration (26100): loss = 0.000, accuracy = 1.000
# iteration (26200): loss = 0.000, accuracy = 1.000
# iteration (26300): loss = 0.026, accuracy = 0.990
# iteration (26400): loss = 0.000, accuracy = 1.000
# validation for epoch 52
# validation result is 0.98560
# test result is 0.98300
# Train for epoch 53
# iteration (26500): loss = 0.000, accuracy = 1.000
# iteration (26600): loss = 0.009, accuracy = 0.990
# iteration (26700): loss = 0.000, accuracy = 1.000
# iteration (26800): loss = 0.000, accuracy = 1.000
# iteration (26900): loss = 0.000, accuracy = 1.000
# validation for epoch 53
# validation result is 0.98930
# test result is 0.98750
# Train for epoch 54
# iteration (27000): loss = 0.000, accuracy = 1.000
# iteration (27100): loss = 0.000, accuracy = 1.000
# iteration (27200): loss = 0.000, accuracy = 1.000
# iteration (27300): loss = 0.054, accuracy = 0.990
# iteration (27400): loss = 0.000, accuracy = 1.000
# validation for epoch 54
# validation result is 0.98500
# test result is 0.98250
# Train for epoch 55
# iteration (27500): loss = 0.036, accuracy = 0.990
# iteration (27600): loss = 0.001, accuracy = 1.000
# iteration (27700): loss = 0.000, accuracy = 1.000
# iteration (27800): loss = 0.000, accuracy = 1.000
# iteration (27900): loss = 0.000, accuracy = 1.000
# validation for epoch 55
# validation result is 0.98630
# test result is 0.98500
# Train for epoch 56
# iteration (28000): loss = 0.001, accuracy = 1.000
# iteration (28100): loss = 0.000, accuracy = 1.000
# iteration (28200): loss = 0.000, accuracy = 1.000
# iteration (28300): loss = 0.001, accuracy = 1.000
# iteration (28400): loss = 0.000, accuracy = 1.000
# validation for epoch 56
# validation result is 0.98750
# test result is 0.98610
# Train for epoch 57
# iteration (28500): loss = 0.002, accuracy = 1.000
# iteration (28600): loss = 0.000, accuracy = 1.000
# iteration (28700): loss = 0.000, accuracy = 1.000
# iteration (28800): loss = 0.000, accuracy = 1.000
# iteration (28900): loss = 0.000, accuracy = 1.000
# validation for epoch 57
# validation result is 0.98770
# test result is 0.98760
# Train for epoch 58
# iteration (29000): loss = 0.000, accuracy = 1.000
# iteration (29100): loss = 0.000, accuracy = 1.000
# iteration (29200): loss = 0.005, accuracy = 1.000
# iteration (29300): loss = 0.197, accuracy = 0.980
# iteration (29400): loss = 0.000, accuracy = 1.000
# validation for epoch 58
# validation result is 0.98600
# test result is 0.98430
# Train for epoch 59
# iteration (29500): loss = 0.001, accuracy = 1.000
# iteration (29600): loss = 0.101, accuracy = 0.990
# iteration (29700): loss = 0.000, accuracy = 1.000
# iteration (29800): loss = 0.002, accuracy = 1.000
# iteration (29900): loss = 0.066, accuracy = 0.990
# validation for epoch 59
# validation result is 0.98660
# test result is 0.98360
# Train for epoch 60
# iteration (30000): loss = 0.007, accuracy = 1.000
# iteration (30100): loss = 0.004, accuracy = 1.000
# iteration (30200): loss = 0.002, accuracy = 1.000
# iteration (30300): loss = 0.000, accuracy = 1.000
# iteration (30400): loss = 0.000, accuracy = 1.000
# validation for epoch 60
# validation result is 0.98690
# test result is 0.98580
# Train for epoch 61
# iteration (30500): loss = 0.000, accuracy = 1.000
# iteration (30600): loss = 0.000, accuracy = 1.000
# iteration (30700): loss = 0.000, accuracy = 1.000
# iteration (30800): loss = 0.000, accuracy = 1.000
# iteration (30900): loss = 0.000, accuracy = 1.000
# validation for epoch 61
# validation result is 0.98780
# test result is 0.98670
# Train for epoch 62
# iteration (31000): loss = 0.000, accuracy = 1.000
# iteration (31100): loss = 0.000, accuracy = 1.000
# iteration (31200): loss = 0.000, accuracy = 1.000
# iteration (31300): loss = 0.000, accuracy = 1.000
# iteration (31400): loss = 0.000, accuracy = 1.000
# validation for epoch 62
# validation result is 0.98590
# test result is 0.98690
# Train for epoch 63
# iteration (31500): loss = 0.000, accuracy = 1.000
# iteration (31600): loss = 0.004, accuracy = 1.000
# iteration (31700): loss = 0.000, accuracy = 1.000
# iteration (31800): loss = 0.000, accuracy = 1.000
# iteration (31900): loss = 0.000, accuracy = 1.000
# validation for epoch 63
# validation result is 0.98590
# test result is 0.98590
# Train for epoch 64
# iteration (32000): loss = 0.000, accuracy = 1.000
# iteration (32100): loss = 0.049, accuracy = 0.990
# iteration (32200): loss = 0.001, accuracy = 1.000
# iteration (32300): loss = 0.000, accuracy = 1.000
# iteration (32400): loss = 0.000, accuracy = 1.000
# validation for epoch 64
# validation result is 0.98450
# test result is 0.98460
# Train for epoch 65
# iteration (32500): loss = 0.000, accuracy = 1.000
# iteration (32600): loss = 0.000, accuracy = 1.000
# iteration (32700): loss = 0.000, accuracy = 1.000
# iteration (32800): loss = 0.000, accuracy = 1.000
# iteration (32900): loss = 0.014, accuracy = 0.990
# validation for epoch 65
# validation result is 0.98650
# test result is 0.98350
# Train for epoch 66
# iteration (33000): loss = 0.001, accuracy = 1.000
# iteration (33100): loss = 0.000, accuracy = 1.000
# iteration (33200): loss = 0.000, accuracy = 1.000
# iteration (33300): loss = 0.000, accuracy = 1.000
# iteration (33400): loss = 0.016, accuracy = 0.990
# validation for epoch 66
# validation result is 0.98770
# test result is 0.98640
# Train for epoch 67
# iteration (33500): loss = 0.000, accuracy = 1.000
# iteration (33600): loss = 0.000, accuracy = 1.000
# iteration (33700): loss = 0.000, accuracy = 1.000
# iteration (33800): loss = 0.000, accuracy = 1.000
# iteration (33900): loss = 0.000, accuracy = 1.000
# validation for epoch 67
# validation result is 0.98660
# test result is 0.98740
# Train for epoch 68
# iteration (34000): loss = 0.000, accuracy = 1.000
# iteration (34100): loss = 0.000, accuracy = 1.000
# iteration (34200): loss = 0.000, accuracy = 1.000
# iteration (34300): loss = 0.000, accuracy = 1.000
# iteration (34400): loss = 0.005, accuracy = 1.000
# validation for epoch 68
# validation result is 0.99020
# test result is 0.98980
# Train for epoch 69
# iteration (34500): loss = 0.000, accuracy = 1.000
# iteration (34600): loss = 0.000, accuracy = 1.000
# iteration (34700): loss = 0.000, accuracy = 1.000
# iteration (34800): loss = 0.000, accuracy = 1.000
# iteration (34900): loss = 0.000, accuracy = 1.000
# validation for epoch 69
# validation result is 0.99020
# test result is 0.99010
# Train for epoch 70
# iteration (35000): loss = 0.000, accuracy = 1.000
# iteration (35100): loss = 0.000, accuracy = 1.000
# iteration (35200): loss = 0.000, accuracy = 1.000
# iteration (35300): loss = 0.000, accuracy = 1.000
# iteration (35400): loss = 0.000, accuracy = 1.000
# validation for epoch 70
# validation result is 0.99020
# test result is 0.99010
# Train for epoch 71
# iteration (35500): loss = 0.000, accuracy = 1.000
# iteration (35600): loss = 0.000, accuracy = 1.000
# iteration (35700): loss = 0.000, accuracy = 1.000
# iteration (35800): loss = 0.000, accuracy = 1.000
# iteration (35900): loss = 0.000, accuracy = 1.000
# validation for epoch 71
# validation result is 0.99040
# test result is 0.98990
# Train for epoch 72
# iteration (36000): loss = 0.000, accuracy = 1.000
# iteration (36100): loss = 0.000, accuracy = 1.000
# iteration (36200): loss = 0.000, accuracy = 1.000
# iteration (36300): loss = 0.000, accuracy = 1.000
# iteration (36400): loss = 0.000, accuracy = 1.000
# validation for epoch 72
# validation result is 0.99060
# test result is 0.99000
# Train for epoch 73
# iteration (36500): loss = 0.000, accuracy = 1.000
# iteration (36600): loss = 0.000, accuracy = 1.000
# iteration (36700): loss = 0.000, accuracy = 1.000
# iteration (36800): loss = 0.000, accuracy = 1.000
# iteration (36900): loss = 0.000, accuracy = 1.000
# validation for epoch 73
# validation result is 0.99080
# test result is 0.98990
# Train for epoch 74
# iteration (37000): loss = 0.000, accuracy = 1.000
# iteration (37100): loss = 0.000, accuracy = 1.000
# iteration (37200): loss = 0.000, accuracy = 1.000
# iteration (37300): loss = 0.000, accuracy = 1.000
# iteration (37400): loss = 0.000, accuracy = 1.000
# validation for epoch 74
# validation result is 0.99080
# test result is 0.98990
# Train for epoch 75
# iteration (37500): loss = 0.000, accuracy = 1.000
# iteration (37600): loss = 0.000, accuracy = 1.000
# iteration (37700): loss = 0.000, accuracy = 1.000
# iteration (37800): loss = 0.000, accuracy = 1.000
# iteration (37900): loss = 0.000, accuracy = 1.000
# validation for epoch 75
# validation result is 0.99070
# test result is 0.98980
# Train for epoch 76
# iteration (38000): loss = 0.000, accuracy = 1.000
# iteration (38100): loss = 0.000, accuracy = 1.000
# iteration (38200): loss = 0.000, accuracy = 1.000
# iteration (38300): loss = 0.000, accuracy = 1.000
# iteration (38400): loss = 0.000, accuracy = 1.000
# validation for epoch 76
# validation result is 0.99080
# test result is 0.98970
# Train for epoch 77
# iteration (38500): loss = 0.000, accuracy = 1.000
# iteration (38600): loss = 0.000, accuracy = 1.000
# iteration (38700): loss = 0.000, accuracy = 1.000
# iteration (38800): loss = 0.000, accuracy = 1.000
# iteration (38900): loss = 0.000, accuracy = 1.000
# validation for epoch 77
# validation result is 0.99090
# test result is 0.98980
# Train for epoch 78
# iteration (39000): loss = 0.000, accuracy = 1.000
# iteration (39100): loss = 0.000, accuracy = 1.000
# iteration (39200): loss = 0.000, accuracy = 1.000
# iteration (39300): loss = 0.000, accuracy = 1.000
# iteration (39400): loss = 0.000, accuracy = 1.000
# validation for epoch 78
# validation result is 0.99090
# test result is 0.98980
# Train for epoch 79
# iteration (39500): loss = 0.000, accuracy = 1.000
# iteration (39600): loss = 0.000, accuracy = 1.000
# iteration (39700): loss = 0.000, accuracy = 1.000
# iteration (39800): loss = 0.000, accuracy = 1.000
# iteration (39900): loss = 0.000, accuracy = 1.000
# validation for epoch 79
# validation result is 0.99090
# test result is 0.98980
# Train for epoch 80
# iteration (40000): loss = 0.000, accuracy = 1.000
# iteration (40100): loss = 0.000, accuracy = 1.000
# iteration (40200): loss = 0.000, accuracy = 1.000
# iteration (40300): loss = 0.000, accuracy = 1.000
# iteration (40400): loss = 0.000, accuracy = 1.000
# validation for epoch 80
# validation result is 0.99090
# test result is 0.98980
# Train for epoch 81
# iteration (40500): loss = 0.000, accuracy = 1.000
# iteration (40600): loss = 0.000, accuracy = 1.000
# iteration (40700): loss = 0.000, accuracy = 1.000
# iteration (40800): loss = 0.000, accuracy = 1.000
# iteration (40900): loss = 0.000, accuracy = 1.000
# validation for epoch 81
# validation result is 0.99090
# test result is 0.99000
# Train for epoch 82
# iteration (41000): loss = 0.000, accuracy = 1.000
# iteration (41100): loss = 0.000, accuracy = 1.000
# iteration (41200): loss = 0.000, accuracy = 1.000
# iteration (41300): loss = 0.000, accuracy = 1.000
# iteration (41400): loss = 0.000, accuracy = 1.000
# validation for epoch 82
# validation result is 0.99080
# test result is 0.99010
# Train for epoch 83
# iteration (41500): loss = 0.000, accuracy = 1.000
# iteration (41600): loss = 0.000, accuracy = 1.000
# iteration (41700): loss = 0.000, accuracy = 1.000
# iteration (41800): loss = 0.000, accuracy = 1.000
# iteration (41900): loss = 0.000, accuracy = 1.000
# validation for epoch 83
# validation result is 0.99080
# test result is 0.99020
# Train for epoch 84
# iteration (42000): loss = 0.000, accuracy = 1.000
# iteration (42100): loss = 0.000, accuracy = 1.000
# iteration (42200): loss = 0.000, accuracy = 1.000
# iteration (42300): loss = 0.000, accuracy = 1.000
# iteration (42400): loss = 0.000, accuracy = 1.000
# validation for epoch 84
# validation result is 0.99080
# test result is 0.98990
# Train for epoch 85
# iteration (42500): loss = 0.000, accuracy = 1.000
# iteration (42600): loss = 0.000, accuracy = 1.000
# iteration (42700): loss = 0.000, accuracy = 1.000
# iteration (42800): loss = 0.000, accuracy = 1.000
# iteration (42900): loss = 0.000, accuracy = 1.000
# validation for epoch 85
# validation result is 0.99080
# test result is 0.98990
# Train for epoch 86
# iteration (43000): loss = 0.000, accuracy = 1.000
# iteration (43100): loss = 0.000, accuracy = 1.000
# iteration (43200): loss = 0.000, accuracy = 1.000
# iteration (43300): loss = 0.000, accuracy = 1.000
# iteration (43400): loss = 0.000, accuracy = 1.000
# validation for epoch 86
# validation result is 0.99080
# test result is 0.99010
# Train for epoch 87
# iteration (43500): loss = 0.000, accuracy = 1.000
# iteration (43600): loss = 0.000, accuracy = 1.000
# iteration (43700): loss = 0.000, accuracy = 1.000
# iteration (43800): loss = 0.000, accuracy = 1.000
# iteration (43900): loss = 0.000, accuracy = 1.000
# validation for epoch 87
# validation result is 0.99070
# test result is 0.99010
# Train for epoch 88
# iteration (44000): loss = 0.000, accuracy = 1.000
# iteration (44100): loss = 0.000, accuracy = 1.000
# iteration (44200): loss = 0.000, accuracy = 1.000
# iteration (44300): loss = 0.000, accuracy = 1.000
# iteration (44400): loss = 0.000, accuracy = 1.000
# validation for epoch 88
# validation result is 0.99070
# test result is 0.99010
# Train for epoch 89
# iteration (44500): loss = 0.000, accuracy = 1.000
# iteration (44600): loss = 0.000, accuracy = 1.000
# iteration (44700): loss = 0.000, accuracy = 1.000
# iteration (44800): loss = 0.000, accuracy = 1.000
# iteration (44900): loss = 0.000, accuracy = 1.000
# validation for epoch 89
# validation result is 0.99070
# test result is 0.99000
# Train for epoch 90
# iteration (45000): loss = 0.000, accuracy = 1.000
# iteration (45100): loss = 0.000, accuracy = 1.000
# iteration (45200): loss = 0.000, accuracy = 1.000
# iteration (45300): loss = 0.000, accuracy = 1.000
# iteration (45400): loss = 0.000, accuracy = 1.000
# validation for epoch 90
# validation result is 0.99070
# test result is 0.98990
# Train for epoch 91
# iteration (45500): loss = 0.000, accuracy = 1.000
# iteration (45600): loss = 0.000, accuracy = 1.000
# iteration (45700): loss = 0.000, accuracy = 1.000
# iteration (45800): loss = 0.000, accuracy = 1.000
# iteration (45900): loss = 0.000, accuracy = 1.000
# validation for epoch 91
# validation result is 0.99070
# test result is 0.98970
# Train for epoch 92
# iteration (46000): loss = 0.000, accuracy = 1.000
# iteration (46100): loss = 0.000, accuracy = 1.000
# iteration (46200): loss = 0.000, accuracy = 1.000
# iteration (46300): loss = 0.000, accuracy = 1.000
# iteration (46400): loss = 0.000, accuracy = 1.000
# validation for epoch 92
# validation result is 0.99070
# test result is 0.98970
# Train for epoch 93
# iteration (46500): loss = 0.000, accuracy = 1.000
# iteration (46600): loss = 0.000, accuracy = 1.000
# iteration (46700): loss = 0.000, accuracy = 1.000
# iteration (46800): loss = 0.000, accuracy = 1.000
# iteration (46900): loss = 0.000, accuracy = 1.000
# validation for epoch 93
# validation result is 0.99070
# test result is 0.98980
# Train for epoch 94
# iteration (47000): loss = 0.000, accuracy = 1.000
# iteration (47100): loss = 0.000, accuracy = 1.000
# iteration (47200): loss = 0.000, accuracy = 1.000
# iteration (47300): loss = 0.000, accuracy = 1.000
# iteration (47400): loss = 0.000, accuracy = 1.000
# validation for epoch 94
# validation result is 0.99070
# test result is 0.98990
# Train for epoch 95
# iteration (47500): loss = 0.000, accuracy = 1.000
# iteration (47600): loss = 0.000, accuracy = 1.000
# iteration (47700): loss = 0.000, accuracy = 1.000
# iteration (47800): loss = 0.000, accuracy = 1.000
# iteration (47900): loss = 0.000, accuracy = 1.000
# validation for epoch 95
# validation result is 0.99080
# test result is 0.99010
# Train for epoch 96
# iteration (48000): loss = 0.000, accuracy = 1.000
# iteration (48100): loss = 0.000, accuracy = 1.000
# iteration (48200): loss = 0.000, accuracy = 1.000
# iteration (48300): loss = 0.000, accuracy = 1.000
# iteration (48400): loss = 0.000, accuracy = 1.000
# validation for epoch 96
# validation result is 0.99060
# test result is 0.99000
# Train for epoch 97
# iteration (48500): loss = 0.000, accuracy = 1.000
# iteration (48600): loss = 0.000, accuracy = 1.000
# iteration (48700): loss = 0.000, accuracy = 1.000
# iteration (48800): loss = 0.000, accuracy = 1.000
# iteration (48900): loss = 0.000, accuracy = 1.000
# validation for epoch 97
# validation result is 0.99080
# test result is 0.99000
# Train for epoch 98
# iteration (49000): loss = 0.000, accuracy = 1.000
# iteration (49100): loss = 0.000, accuracy = 1.000
# iteration (49200): loss = 0.000, accuracy = 1.000
# iteration (49300): loss = 0.000, accuracy = 1.000
# iteration (49400): loss = 0.000, accuracy = 1.000
# validation for epoch 98
# validation result is 0.99090
# test result is 0.98990
# Train for epoch 99
# iteration (49500): loss = 0.000, accuracy = 1.000
# iteration (49600): loss = 0.000, accuracy = 1.000
# iteration (49700): loss = 0.000, accuracy = 1.000
# iteration (49800): loss = 0.000, accuracy = 1.000
# iteration (49900): loss = 0.000, accuracy = 1.000
# validation for epoch 99
# validation result is 0.99090
# test result is 0.98980

# %%
model = SaakNet()
model = model.cuda()
valid_image = valid_image[:100,:]
valid_ima = Variable(torch.from_numpy(valid_image))
valid_ima = valid_ima.cuda()
output = model(valid_ima)
# Out:
# torch.Size([100, 4001, 1, 1])
# torch.Size([100, 4001])
# torch.Size([100, 667])
# torch.Size([100, 111])
# torch.Size([100, 10])
